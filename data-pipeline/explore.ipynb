# %%
# %reload_ext autoreload
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import sqlite3
import hashlib
import time
from sqlalchemy import text, inspect, MetaData, Table, func
from sqlalchemy.orm import sessionmaker
from app.main import getTables, Base, Account, Transaction, TransactionFinal, Load
from app.helpers.readCsv import openOneCsv, getAccountHistory, setDateColumns
from app.helpers.sqlEngine import engine
from app.helpers.summarize import summarize
from app.helpers.query_to_df import query_to_df

from app.crud.delete.truncate_all import truncate_all
from app.crud.read.select_accounts_df import select_accounts_df
from app.crud.read.select_unique_staged_transactions import select_unique_staged_transactions
from app.crud.read.select_final_transactions import select_final_transactions
from app.crud.create.insert_query_into_table import insert_query_into_table

from app.etl.full_load_from_csv import full_load_from_csv

pd.set_option('display.max_rows', 60)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('max_colwidth', 1000)

query = select_final_transactions(engine)
df = query_to_df(query)

# %%
summarize('art', df)

# %%
describe('publix', df)

# %%
describe('publix', df_final)

# %%
describe('publix', df)
